# %%
# %matplotlib inline

import visuals
import numpy as np
import pandas as pd
from product import Product
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs
from product_transform import Transform

products = Product().get_all()
"""
Examine the word count for each product specification and detrimine the avarage.
"""
visuals.plot_word_count_graph()
# Out:
# RMS word count is 453
# Average word count is 451
# Maximum word count is 633
# Minimum word count is 305

# %%
from IPython.display import HTML, display
from tabulate import tabulate

"""
Compare the specs. for the product with the highest and lowest word count.
"""
word_counts = np.array(visuals.get_product_spec_word_counts())

# Get product indices for the product with the lowest word 
# count and the product with the highest word count.
product_max_word_count = products[word_counts.argmax()]
product_min_word_count = products[word_counts.argmin()]

# Build and display the table.
table = [["Product ID", product_max_word_count['id'], product_min_word_count['id']],
         ["Word count", word_counts.max(), word_counts.min()],
         ["Specs.", product_max_word_count['specification'], product_min_word_count['specification']]]


display(HTML(tabulate(table, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>Product ID</td><td>20352                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# <tr><td>Word count</td><td>633

# %%
"""
The information under General, Ports and Media Format better describe the attributes of the product.
Let's check if this information is available to all products.
"""


def check_info_exists(key):
    
    missing_count = 0
    for product in products:
        
        """
        Each HTML <ul> tag contains an id i.e <ul id="general"> we 
        loop over each product's spec. to see if the id exists
        within the content.
        """
        soup = bs(product['specification'], 'html.parser')
        tag = soup.find(id=key)
        if not tag or (tag.contents == 0):
            missing_count += 1
    
    if missing_count > 0:
        print('{} info could not be found for {} product(s)'.format(key, missing_count))
    else:
        print('All products have %s spec.' % key)

        
check_info_exists('general')
check_info_exists('Ports')
check_info_exists('Media_Formats')
# Out:
# All products have general spec.
# All products have Ports spec.
# All products have Media_Formats spec.

# %%
"""
Now we have confirmed that each product spec. contains the required info. 
let's re-examine our word counts for only this data.
"""
visuals.plot_word_count_graph(refine_spec=True)
# Out:
# RMS word count is 109
# Average word count is 108
# Maximum word count is 148
# Minimum word count is 70

# %%
from pprint import pprint

"""
List the related item ids that have been manually selected for the first product.
"""
print('Related items for product id {}:'.format(products[0]['id']))
pprint(products[0]['related'])
# Out:
# Related items for product id 20673:
# [{'product_id': 19830},
#  {'product_id': 20242},
#  {'product_id': 20654},
#  {'product_id': 20846},
#  {'product_id': 20964},
#  {'product_id': 20965},
#  {'product_id': 21092},
#  {'product_id': 21098},
#  {'product_id': 21104},
#  {'product_id': 21492}]

# %%
from engine import Engine, matching_score
"""
Display a table of the parent product's refined spec. 
againest two related items refined spec..
"""

parent = products[0]
item_1 = Product().find_by_id(19830)
item_2 = Product().find_by_id(20242)

# Build and display the table
table = [
    ['Product ID', parent['id'], item_1['id'], item_2['id']],
    ['Product name', parent['short_name'], item_1['short_name'], item_2['short_name']],
    ['Spec.', 
     Transform(parent).get('specification').refined().text(),
     Transform(item_1).get('specification').refined().text(),
     Transform(item_2).get('specification').refined().text()],
    ['', 'Matching score:', matching_score(parent['id'], item_1['id']), matching_score(parent['id'], item_2['id'])]
]

display(HTML(tabulate(table, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td>Product ID  </td><td>20673             </td><td>19830            </td><td>20242             </td></tr>
# <tr><td>Product name</td><td>V88 Android TV Box</td><td>F7 Android TV Box</td><td>MXQ Android TV Box</td></tr>
# <tr><td>Spec.       </td><td>OS Version: Android 5.1
# CPU: Rock Chip 3229 Quad-Core
# GPU: Mali-400MP
# Processor Speed (max): 1.46GHz
# RAM: 1GB
# Internal Memory: 8GB
# External Memory: Support up to 16GB
# Display Resolution: 4K x 2K
# Supported Video Resolution: 4K x 2K
# Wi­Fi: 802.11 b/g/n
# Google Play
# Kodi 16.1
# 3D Movie Support
# HDMI
# RJ45 port
# AV out
# Micro SD Card Slot: up to 16GB
# 4xUSB Port
# SPDIF
# DC IN
# Video: MKV, WMV/VC-1 SP/MP/AP, MPG, MPEG, DAT, AVI, MOV, ISO, MP4, RM, H.264, H.265, RealVideo 8/9/10, VP8/9, up to 2160P
# Audio: MP3, AAC, WMA, RM, FLAC, OGG
# Graphic: JPG, JPEG, MJPEG, PNG                   </td><td>OS Version: Android 4.4
# CPU: Rock Chip 3218 Quad-Core
# Processor Speed (max): 1.2GHz
# RAM: 1GB
# Internal Memory: 8GB
# External Memory: Support up to 32GB
# Display Resolution(max): 1920x1080
# Wi-Fi: 802.11 b/g/n
# Bluetooth
# DLNA
# Miracast
# Airplay
# Google Play
# Supported XBMC, Kodi
# AV Out
# Mini HDMI
# LAN
# OTG
# SPDIF
# DC IN
# Micro SD Card Slot
# 2x USB
# Video: MP4, 3GP, AVI
# Audio: MP3, WMA, WAV
# Graphic: JPG, GIF, PNG, BMP
# eBook: PDF, TXT                  </td><td>OS Version: Android 4.4
# CPU: Amlogic S805 Quad-Core Cortex-A5
# GPU: Quad-Core Mali-45
# Processor Speed (max): 1.6GHz
# RAM: 1GB
# Internal Memory: 8GB
# External Memory: Support up to 32GB
# Display Resolution(max):1920x1080
# Support Video Resolution(max): 4K x 2K
# Wi-Fi: 802.11 b/g/n
# Google Play
# DLNA
# Miracast
# Airplay
# Kodi / XBMC 16.0
# HDMI
# 4x USB
# SPDIF
# SD card slots
# AV port
# RJ45 port
# DC IN
# Video: AVI, RM, RMVB, Ts, VOB, MKV, MOV, ISO, WMV, ASF, FLV, DAT, MPG, MPEG
# Audio: MP3, WMA, AAC, WAV, OGG, AC3, DDP, TrueHD, DTS, DTS, HD, FLAC, APE
# Graphic: HD JPEG, BMP, GIF, PNG, TIFF
# eBook: PDF, TXT                   </td></tr>
# <tr><td>            </td><td>Matching score:   </td><td>0.4375           </td><td>0.5416666666666666</td></tr>
# </tbody>
# </table>

# %%
"""
Train engine using meta keywords and plot graph.
"""
engine = Engine()
engine.train_on('meta_keyword')

scores = engine.get_product_similarity_scores(20673)
visuals.plot_product_scores(20673, scores[:5])

print('-' * 50)
for item in products[0]['related'][:3]:
    print('Similarity score for manually selected item ID {0}: {1}'.format(
        item['product_id'],
        engine.get_similar_score_for_item(item['product_id'], scores)
    ))
# Out:
# Training data ingested in 0.04993033409118652 seconds.
# Engine trained in 0.0027942657470703125 seconds.
# Similarity scores: [0.95262357652386098, 0.91339225094695753, 0.8952875131200031, 0.86932771677820808, 0.85353790788640294]
# Matching scores: [0.5520833333333334, 0.5625, 0.59375, 0.5520833333333334, 0.5833333333333334]
# Mean difference: 0.3280837930510865
# --------------------------------------------------
# Similarity score for manually selected item ID 19830: 0.6716423605537551
# Similarity score for manually selected item ID 20242: 0.7885452402726609
# Similarity score for manually selected item ID 20654: 0.8054023180955576

# %%
"""
Train engine using overview and plot graph.
"""
engine.train_on('overview')

scores = engine.get_product_similarity_scores(20673)
visuals.plot_product_scores(20673, scores[:5])

print('-' * 50)
for item in products[0]['related'][:3]:
    print('Similarity score for manually selected item ID {0}: {1}'.format(
        item['product_id'],
        engine.get_similar_score_for_item(item['product_id'], scores)
    ))
# Out:
# Training data ingested in 0.03920769691467285 seconds.
# Engine trained in 0.019956350326538086 seconds.
# Similarity scores: [0.42370707992718382, 0.39481599180568583, 0.39454664540923767, 0.34731611733505979, 0.33785643756009986]
# Matching scores: [0.8541666666666666, 0.5520833333333334, 0.78125, 0.6354166666666666, 0.5833333333333334]
# Mean difference: 0.3016015455925466
# --------------------------------------------------
# Similarity score for manually selected item ID 19830: 0.2400155595688003
# Similarity score for manually selected item ID 20242: 0.3225586796983039
# Similarity score for manually selected item ID 20654: 0.2226086345101015

# %%
"""
Train engine using specification and plot graph.
"""
engine.train_on('specification')

scores = engine.get_product_similarity_scores(20673)
visuals.plot_product_scores(20673, scores[:5])

print('-' * 50)
for item in products[0]['related'][:3]:
    print('Similarity score for manually selected item ID {0}: {1}'.format(
        item['product_id'],
        engine.get_similar_score_for_item(item['product_id'], scores)
    ))
# Out:
# Training data ingested in 0.15392374992370605 seconds.
# Engine trained in 0.022634029388427734 seconds.
# Similarity scores: [0.88865245112099234, 0.87871093653827226, 0.83622690130682775, 0.82491392698881338, 0.79477415167587462]
# Matching scores: [0.7708333333333334, 0.78125, 0.65625, 0.8541666666666666, 0.5520833333333334]
# Mean difference: 0.1217390068594894
# --------------------------------------------------
# Similarity score for manually selected item ID 19830: 0.6527189525424484
# Similarity score for manually selected item ID 20242: 0.6454848488572131
# Similarity score for manually selected item ID 20654: 0.6299257247262344

# %%
"""
Train engine using refined specification and plot graph.
"""
tf = engine.train_on('refined_specification')

scores = engine.get_product_similarity_scores(20673)
visuals.plot_product_scores(20673, scores[:5])

print('-' * 50)
scores = engine.get_product_similarity_scores(20673)

print('-' * 50)
for item in products[0]['related'][:3]:
    print('Similarity score for manually selected item ID {0}: {1}'.format(
        item['product_id'],
        engine.get_similar_score_for_item(item['product_id'], scores)
    ))
    
print('Vocabulary size: %d' % len(tf.vocabulary_))
# Out:
# Training data ingested in 0.2570505142211914 seconds.
# Engine trained in 0.007715940475463867 seconds.
# Similarity scores: [0.92815576739235861, 0.9192998980125251, 0.89474257728493189, 0.77615819937238406, 0.69382212460395443]
# Matching scores: [0.78125, 0.7708333333333334, 0.8541666666666666, 0.78125, 0.6666666666666666]
# Mean difference: 0.07160237999989749
# --------------------------------------------------
# --------------------------------------------------
# Similarity score for manually selected item ID 19830: 0.3718338650048829
# Similarity score for manually selected item ID 20242: 0.35353647474881744
# Similarity score for manually selected item ID 20654: 0.44245911916543096
# Vocabulary size: 359

# %%
"""
Remove words that don't apper in at least two product refined specs.
Plot scores for 3 differnet porducts.
"""
tf = engine.train_on('refined_specification', min_df=2)

ids = [20673, 21492, 20964]
for i in ids:
    print("Graph for product ID %d" % i)
    scores = engine.get_product_similarity_scores(i)[:5]
    visuals.plot_product_scores(i, scores)

    
print('Vocabulary size: %d' % len(tf.vocabulary_))
# Out:
# Training data ingested in 0.2590608596801758 seconds.
# Engine trained in 0.008033275604248047 seconds.
# Graph for product ID 20673
# Similarity scores: [0.98601929762579454, 0.92815576739235861, 0.9192998980125251, 0.77615819937238406, 0.69382212460395443]
# Matching scores: [0.8541666666666666, 0.78125, 0.7708333333333334, 0.78125, 0.6666666666666666]
# Mean difference: 0.08985772406807002
# Graph for product ID 21492
# Similarity scores: [0.62137366183825538, 0.58878330605519624, 0.58739284616400833, 0.57099844448828596, 0.56150394392833958]
# Matching scores: [0.5643564356435643, 0.5742574257425742, 0.5643564356435643, 0.594059405940594, 0.5742574257425742]
# Mean difference: 0.011753014752242885
# Graph for product ID 20964
# Similarity scores: [0.88281570543267218, 0.87449062336714845, 0.83613025717532907, 0.82999898229884139, 0.81433852707530618]
# Matching scores: [0.8130841121495327, 0.8130841121495327, 0.794392523364486, 0.719626168224299, 0.7570093457943925]
# Mean difference: 0.06811556673341088
# Vocabulary size: 240

# %%
"""
Remove words that don't apper in at least two product refined specs.
Use pair words instead i.e ['android 5.1'] instead if single words ['android' '5.1'].
Plot scores for 3 differnet porducts.
"""

tf = engine.train_on('refined_specification', min_df=2, ngram_range=(2,2))

ids = [20673, 21492, 20964]
for i in ids:
    print("Graph for product ID %d" % i)
    scores = engine.get_product_similarity_scores(i)[:5]
    visuals.plot_product_scores(i, scores)
    
print('Vocabulary size: %d' % len(tf.vocabulary_))
# Out:
# Training data ingested in 0.2433459758758545 seconds.
# Engine trained in 0.010556936264038086 seconds.
# Graph for product ID 20673
# Similarity scores: [0.97561067970561788, 0.84241209435537834, 0.83006260805165799, 0.62903819636213509, 0.53619884466991108]
# Matching scores: [0.8541666666666666, 0.78125, 0.7708333333333334, 0.78125, 0.6666666666666666]
# Mean difference: 0.00816884870439325
# Graph for product ID 21492
# Similarity scores: [0.50685295340328806, 0.50431789634069835, 0.47371772544038726, 0.47182672743223386, 0.4458611084166153]
# Matching scores: [0.594059405940594, 0.6039603960396039, 0.594059405940594, 0.5643564356435643, 0.6039603960396039]
# Mean difference: 0.11156392571414749
# Graph for product ID 20964
# Similarity scores: [0.75154699381665824, 0.68458927467746644, 0.65221855151356167, 0.63083970155510805, 0.62522660461560464]
# Matching scores: [0.8130841121495327, 0.8130841121495327, 0.794392523364486, 0.719626168224299, 0.7570093457943925]
# Mean difference: 0.11055502710076877
# Vocabulary size: 529

# %%
"""
Print score for manually selected related items for product 21492
"""
product = Product().find_by_id(21492)
scores = engine.get_product_similarity_scores(21492)

print('Scores for manually selected related items for product 21492:\n')
for item in product['related']:
    print('-' *50) 
    print('Results for product ID %d' % item['product_id'])
    print('Similarity score: %s' % engine.get_similar_score_for_item(item['product_id'], scores))
    print('Matching score: %s' % matching_score(21492, item['product_id']))
# Out:
# Scores for manually selected related items for product 21492:
#
# --------------------------------------------------
# Results for product ID 19617
# Similarity score: 0.231071880532
# Matching score: 0.4752475247524752
# --------------------------------------------------
# Results for product ID 20346
# Similarity score: 0.151756321798
# Matching score: 0.5544554455445545
# --------------------------------------------------
# Results for product ID 20673
# Similarity score: 0.428817085675
# Matching score: 0.594059405940594
# --------------------------------------------------
# Results for product ID 20924
# Similarity score: 0.197964753663
# Matching score: 0.5643564356435643
# --------------------------------------------------
# Results for product ID 21104
# Similarity score: 0.301311767044
# Matching score: 0.5544554455445545
# --------------------------------------------------
# Results for product ID 21503
# Similarity score: 0.506852953403
# Matching score: 0.594059405940594
# --------------------------------------------------
# Results for product ID 21504
# Similarity score: 0.504317896341
# Matching score: 0.6039603960396039
